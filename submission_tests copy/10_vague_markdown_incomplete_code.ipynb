# %% [markdown]
# # Test 10 — Vague markdown, incomplete code
# Top comment: Student writes a vague explanation and leaves TODOs without implementation.

# %% [markdown]
# I will compute Table 3. I think the dp predictor matters. TODO: implement compute_monthly_stats.

# %%
# TODO: fill in code.
# Not implemented.
df_results = None
