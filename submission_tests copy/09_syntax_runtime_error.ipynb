# %% [markdown]
# # Test 09 — Syntax/runtime error
# Top comment: This submission contains a syntax error (missing parenthesis) causing runtime failure.

# %%
import pandas as pd
p = Path.cwd() / 'data' / 'GW05_original_monthly.csv'
df = pd.read_csv(p, sep=';', decimal=',')
# Syntax error below (missing parenthesis)
df['date'] = pd.to_datetime(df['yyyymm'], format='%Y%m'
df.set_index('date', inplace=True)
df_results = pd.DataFrame({'IS_R2_head': []})
df_results
